# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
data1 = pd.read_csv("data_real.csv", sep=",")
data1 = data1.drop(["Unnamed: 0"], axis=1)

# data2 = pd.read_csv("data_intervention_B.csv", sep=",")
# data2 = data2.drop(["Unnamed: 0"], axis=1)

# %%
fig, axs = plt.subplots(4, 4)
fig.set_size_inches(35, 35)
fig.suptitle('Epic gamer moment')

columns = ['A', 'B', 'C', 'D']
for i in range(4):
    for j in range(4):
        axs[i,j].scatter(data1[columns[i]], data1[columns[j]])

plt.show()

# %%
columns = ['A', 'B', 'C', 'D']

for i in range(4):
    sns.distplot(data1[columns[i]], kde=False, label='Without Intervention')
    sns.distplot(data2[columns[i]], kde=False, label='With Intervention')

    # Plot formatting
    plt.legend(prop={'size': 12})
    plt.title('Impact of Intervention')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.show()
# Out:
# C:\Users\magnu\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18224/1484127823.py in <module>
#       3 for i in range(4):
#       4     sns.distplot(data1[columns[i]], kde=False, label='Without Intervention')
# ----> 5     sns.distplot(data2[columns[i]], kde=False, label='With Intervention')
#       6
#       7     # Plot formatting
#
# NameError: name 'data2' is not defined
