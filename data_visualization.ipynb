# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
data1 = pd.read_csv("no_interventions.csv", sep=",")
data1 = data1.drop(["Unnamed: 0"], axis=1)

data2 = pd.read_csv("E_-2.csv", sep=",")
data2 = data2.drop(["Unnamed: 0"], axis=1)

# %%
np.mean(data1['F'])
# Out:
# -0.7479583698267538

# %%
columns = ['A', 'B', 'C', 'D', 'E', 'F']

fig, axs = plt.subplots(len(columns), len(columns))
fig.set_size_inches(35, 35)
fig.suptitle('Epic gamer moment')

for i in range(len(columns)):
    for j in range(len(columns)):
        axs[i,j].scatter(data1[columns[i]], data1[columns[j]])

plt.show()

# %%
columns = ['A', 'B', 'C', 'D', 'E', 'F']

for i in range(len(columns)):
    # sns.distplot(data1[columns[i]], kde=False, norm_hist=True, label='Without Intervention')
    # sns.distplot(data2[columns[i]], kde=False, norm_hist=True, label='With Intervention')

    sns.distplot(data1[columns[i]], norm_hist=True, label='Without Intervention')
    sns.distplot(data2[columns[i]], norm_hist=True, label='With Intervention')


    # Plot formatting
    plt.legend(prop={'size': 12})
    plt.title('Impact of Intervention')
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.show()
